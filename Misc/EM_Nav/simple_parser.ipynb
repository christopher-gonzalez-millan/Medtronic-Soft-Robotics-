# %%
reply = "020A+00083+02303+09730-00115+013641-004923-030312+013550002003F000178C60B+00190-05956+08006+00618-003424-017684-006547+026020002003D000178C60000"

numHandles = reply[0:2]; 
print("numHandles:" + numHandles);

# <== Handle 1 ==>
handle1 = reply[2:4]; 
print("\nHandle1: " + handle1);

# Quaternion
Q0 = float(reply[5] + "." + reply[6:10]); 
if (reply[4] == "-"):
    Q0 *= -1;
    
Qx = float(reply[11] + "." + reply[12:16]); 
if (reply[10] == "-"):
    Qx *= -1;
    
Qy = float(reply[17] + "." + reply[18:22]); 
if (reply[16] == "-"):
    Qy *= -1;        
    
Qz = float(reply[23] + "." + reply[24:28]);
if (reply[22] == "-"):
    Qz *= -1;
print("\tQ0: " + str(Q0) + "\tQx: " + str(Qx) + "\tQy:" + str(Qy) + "\tQz:" + str(Qz));


# Tool positioning
Tx = float(reply[29:33] + "." + reply[33:35]); 
if (reply[28] == "-"):
    Tx *= -1;

Ty = float(reply[36:40] + "." + reply[40:42]); 
if (reply[35] == "-"):
    Ty *= -1;
    
Tz = float(reply[43:47] + "." + reply[47:49]); 
if (reply[42] == "-"):
    Tz *= -1;

print("\tTx: " + str(Tx) + "\tTy: " + str(Ty) + "\tTz:" + str(Tz));

# Indicator value
indValue = float(reply[50] + "." + reply[50:55]);
if (reply[49] == "-"):
    Tz *= -1;
print("\tIndicator value: " + str(indValue));



# <== Handle 2 ==>
handle2 = reply[71:73]; 
print("\nHandle2: " + handle2);

# Quaternion
Q0 = float(reply[74] + "." + reply[75:79]); 
if (reply[73] == "-"):
    Q0 *= -1;
    
Qx = float(reply[80] + "." + reply[81:85]); 
if (reply[79] == "-"):
    Qx *= -1;
    
Qy = float(reply[86] + "." + reply[87:91]); 
if (reply[85] == "-"):
    Qy *= -1;        
    
Qz = float(reply[92] + "." + reply[93:97]);
if (reply[91] == "-"):
    Qz *= -1;
print("\tQ0: " + str(Q0) + "\tQx: " + str(Qx) + "\tQy:" + str(Qy) + "\tQz:" + str(Qz));

# Tool positioning
Tx = float(reply[98:102] + "." + reply[102:104]); 
if (reply[97] == "-"):
    Tx *= -1;

Ty = float(reply[105:109] + "." + reply[109:111]); 
if (reply[104] == "-"):
    Ty *= -1;
    
Tz = float(reply[112:116] + "." + reply[116:118]); 
if (reply[111] == "-"):
    Tz *= -1;

print("\tTx: " + str(Tx) + "\tTy: " + str(Ty) + "\tTz:" + str(Tz));

# Indicator value
indValue = float(reply[119] + "." + reply[120:125]);
if (reply[118] == "-"):
    Tz *= -1;
print("\tIndicator value: " + str(indValue));
# Out:
# numHandles:02
#
# Handle1: 0A
# 	Q0: 0.0083	Qx: 0.2303	Qy:0.973	Qz:-0.0115
# 	Tx: 136.41	Ty: -49.23	Tz:-303.12
# 	Indicator value: 0.01355
#
# Handle2: 0B
# 	Q0: 0.019	Qx: -0.5956	Qy:0.8006	Qz:0.0618
# 	Tx: -34.24	Ty: -176.84	Tz:-65.47
# 	Indicator value: 0.2602
